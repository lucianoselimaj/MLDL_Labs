# %% [markdown]
# <a href="https://colab.research.google.com/github/lucianoselimaj/MLDL_Labs/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# What is Matplotlib?
# Matplotlib is a tool in Python that lets you make graphs and charts, like:
#
# **Line charts**
#
# **Bar charts** --> Compares values between categories
#
# **Scatter plots**
#
# **Histograms** --> Shows the distribution of numeric data

# %% [markdown]
# # **1. Figure: The Full Picture** <br>
# What is it? <br>
# It's the entire window or image where your chart(s) will appear.
# <br><br>
# Think of it like:
# A blank canvas or a piece of paper.

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

# %% [markdown]
# # **2. Axes: One Full Chart** <br>
# What is it?<br>
# * One complete chart inside the figure. It has:
# * The actual graph (like a line plot or bar chart)
# * X and Y axes
# * Titles, labels, gridlines, etc.
#
# Think of it like:
# A box on your canvas that shows a graph. <br><br>
#
# 💡 A single figure can hold multiple axes (charts) using **plt.subplots(rows, columns).**

# %%
fig, ax = plt.subplots() # ax is your chart

ax.plot([1, 2, 3], [4, 5, 6])  # draw a line on it

# %% [markdown]
# ***3. Axis: The X and Y Rulers***
# What is it? <br>
# Each chart (Axes) has two sides:
# * The X-axis (horizontal)
# * The Y-axis (vertical)
#
# They show:
# * Tick marks (1, 2, 3…)
# * Labels ("Time", "Price", etc.)
#
# Think of it like: <br>
# The rulers or scales that go along the sides of a graph.

# %%
ax.set_xlabel('Time')
ax.set_ylabel('Temperature')
# Out:
# Text(4.444444444444452, 0.5, 'Temperature')

# %%
import matplotlib.pyplot as plt

# Step 1: Create a figure with 2 rows and 3 columns of subplots
fig, axes = plt.subplots(2, 3, figsize=(12, 6))  # Optional: figsize controls overall size

# Step 2: Loop through each Axes to set labels and titles
for i in range(2):          # rows
    for j in range(3):      # columns
        ax = axes[i, j]     # Get the subplot at position (i, j) --> selects each subplot

        # Example: plot something (optional)
        ax.plot([0, 1], [i+j, i+j+1])

        # Set x-axis label and title
        ax.set_xlabel(f"x-axis ({i},{j})")
        ax.set_title(f"Title ({i},{j})")

# Step 3: Adjust layout to avoid overlapping labels
plt.tight_layout()

# Step 4: Show the whole figure
plt.show()

# %% [markdown]
# Matplotlib gives us two main ways to write the code.

# %% [markdown]
# # **1. Pyplot interface**: mainly used when whe have to plot a single and simpler graphic

# %%
import matplotlib.pyplot as plt

#data points we want to plot (1,10), (2,15), (3,13), (4,18), (5,16)
x = [1,2,3,4,5]
y= [10,15,13,18,16]

#this draws the line chart connecting those points
plt.plot(x,y)

#adds a title
plt.title('Simple line Plot')

#x and y labels
plt.xlabel('X axis')
plt.ylabel('Y axis')

#display the chart
plt.show() # remmeber that without this line, nothing appears

# %% [markdown]
# # **2. Object oriented**:
# instead of using automatic plotting like plt.plot(), this method gives us more control. We can create the plot objects(figure and axes), and then use their methods to draw and customize. <br><br>
#
# this is especially useful when we're:
# *   Creating multiple charts in one figure
# *   Adding annotations or shapes
# *   Making comple or high customized plots

# %%
import matplotlib.pyplot as plt



#Firs of all create the figure and axes(subplots)
'''
1. fig is the Figure object (the canvas)
2. ax is the Axes object (the chart)

Now you can control them separately:
fig = the full window
ax = one specific chart area inside that window
'''
fig, ax = plt.subplots()

# Plot data on the axis
x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 18, 16]


#Optional: we can set the figure size
fig.set_size_inches(10, 10)

#draw the plot, remember that we are using the obj oriented method so we plot using the ax not the figure
ax.plot(x,y)

#set title and labels of the provided axes
ax.set_title("Simple Line Plot")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")

#show the plot
plt.show()

# %% [markdown]
# # **SUBPLOTS**
# we use subplots when we want to show more than one chart in the same figure(canvas). <br>
# We can think it as a grid within the figure (like rows and columns), where each cell in the grid is a separate chart (axes)

# %%
import matplotlib.pyplot as plt

#we crate a 2-row and 2-column grid of subplots, so in total we have 4 charts
# fig is the cnavas
#ax is like a 2d array (ax[0,0],ax[0,1], etc...)
fig, ax = plt.subplots(2,2, figsize=(6,4))

#draw subplot charts
ax[0,0].plot([0, 1, 2], [2, 4, 6])
ax[1,1].plot([0, 1, 2], [3,6,9])

#automatically adjusts the layout so charts don't overlap each other
plt.tight_layout()

plt.show()

# %% [markdown]
# # **Custom Subplots layout**

# %% [markdown]
# # **1. plt.subplot_mosaic()**
# while plt.subplots() makes a grid like 2x2, sometimes we want a layout that isn't **perfectly rectangular**. <br><br>
# For example, maybe:
# *   One plot should be big across the top
# *   Two smaller plots below it
#
# that's where .subplots_mosaic() helps

# %%
import matplotlib.pyplot as plt

#this creates a custom layout
fig, ax = plt.subplot_mosaic("""
AAABB
AAABB
AAACD
""", figsize=(5, 3))

'''
Layout Diagram (rows of characters):
Row 1: A A A B B
Row 2: A A A B B
Row 3: A A A C D

"A" fills the big top-left area (3 wide, 3 tall)
"B" is to the right of A (2 wide, 2 tall)
"C" and "D" are small plots at the bottom right
'''

#plot a line chart in the section A
ax["A"].plot([1, 2, 3], [1, 2, 3])
#plots a line chart in the section B
ax["B"].plot([1, 2, 3], [3, 2, 1])
ax["C"].plot([1, 2, 3], [-1, 1, -1])
ax["D"].plot([1, 2, 3], [1, -1, 1])

#auto-adjusting
plt.tight_layout()
plt.show()

# %% [markdown]
# # **2. Line Plot: plt.plot(x,y)**
# used to show the **trends over** time or progression(e.g sales over months)

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

#connects the data points, creating the line
plt.plot(x, y)

#set title and labels
plt.title("Line Plot")
plt.xlabel("X")
plt.ylabel("Y")

#shows the chart
plt.show()

# %% [markdown]
# # **3. Scatter plot:plt.scatter(x,y)**
# used to show individual ponts and patterns, like correlations

# %%
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]

#draws only the points
plt.scatter(x, y)

plt.title("Scatter Plot")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %% [markdown]
# # **4. Bar chart: plt.bar(x,height):**
# used to compare data (e.g products, peole, etc...)

# %%
#bar label
x = ["A", "B", "C"]
#bar height (the value)
height = [5, 7, 3]

plt.bar(x, height)

plt.title("Bar Chart")
plt.ylabel("Score")

plt.show()

# %% [markdown]
# # **5. Histogram: plt.hist(data, bins=n):**
# used to show how data is distributed (like ages, scores, etc...)

# %%
data = [1, 2, 2, 3, 3, 3, 4, 4, 5]

#plots the distribution, using the bins (number of bars used)
plt.hist(data, bins=5)

plt.title("Histogram")

plt.show()

# %% [markdown]
# # **6. Pie chart: plt.pie(data, labels=labels):**
# used to show percentages or part of a whole

# %%
#pie sizes
sizes = [40, 35, 25]
#pie labels
labels = ["A", "B", "C"]

#build the pie chart
plt.pie(sizes, labels=labels)

plt.title("Pie Chart")
plt.show()

# %% [markdown]
# # **7. Box Plot: plt.boxplot(data)**
# used to see the **median**, **spread**, **outliers** in our data. <br>
# Shows min, max, median, and outliers

# %%
import matplotlib.pyplot as plt

data = [5, 7, 8, 9, 10, 11, 15, 18, 21]

plt.boxplot(data)
plt.title('Box Plot')
plt.show()

# %% [markdown]
# # **8.Heat Map: plt.imshow(data, cmap='viridis')**
# used to visualize 2D data or intensity levels, like temperatures or correlations

# %%
import numpy as np
data = np.array([[1, 2], [3, 4]])

#we have to provide data and the color map to be used
plt.imshow(data, cmap='viridis')
plt.title('Heatmap')
#adds the color scale near the plot
plt.colorbar()
plt.show()

# %% [markdown]
# | Plot Type | Function        | Use Case                    |
# | --------- | --------------- | --------------------------- |
# | Line      | `plt.plot(x,y)`    | Show trends                 |
# | Scatter   | `plt.scatter(x,y)` | Show patterns/relationships |
# | Bar       | `plt.bar(x, height)`     | Compare categories          |
# | Histogram | `plt.hist(data, bins=n)`    | Show frequency distribution |
# | Pie       | `plt.pie(data, labels=labels)`     | Show parts of a whole       |
# | Box Plot  | `plt.boxplot(data)` | Show spread & outliers      |
# | Heatmap   | `plt.imshow(data, cmap='viridis')`  | Show intensity or 2D data   |

# %% [markdown]
# # **Customization in Matplotlib**
# Customization means changing how your plots look:
# * Add titles, labels, legends
# * Change colors, line styles, markers
# * Add grids, ticks, and more

# %% [markdown]
# # **1. Labels and Titles**

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2, 4, 6]

plt.plot(x, y)
plt.title("My Line Chart")         # Title on top
plt.xlabel("X Axis Label")         # Label under X-axis
plt.ylabel("Y Axis Label")         # Label beside Y-axis
plt.show()

# %% [markdown]
# # **Grid Lines**
# helps you read exact values on the chart

# %%
plt.grid(True) #Adds grid lines to the background, we can use it before plt.plot()

# %% [markdown]
# # **Legend**
# useful when we draw multiple lines, so you know which is which

# %%
x = [1, 2, 3, 4, 5]
y1 = [10, 20, 15, 25, 30]
y2 = [30, 25, 20, 15, 10]


fig, ax = plt.subplots()

#First line
ax.plot(x, y1, label='Line A', color='blue')
#second line
ax.plot(x, y2, label='Line B', color='green')

ax.set_title('Graph. with Legend')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

# Shows the legend box
ax.legend()
#add the background grid
ax.grid(True)

plt.show()

# %% [markdown]
# # **Customizing Colors, Styles, and Markers**
# we can change:
#
# * Line color: color="blue"
# * Line style: linestyle="--" (dashed), "-" (solid)
# * Point marker: marker="o" (circle), "x", "^" (triangle), etc.

# %%
x = [1, 2, 3, 4, 5]
y1 = [10, 20, 15, 25, 30]
y2 = [30, 25, 20, 15, 10]


fig, ax = plt.subplots()

ax.plot(x, y1, label="Line A", color="blue", linestyle="--", marker="o")
ax.plot(x, y2, label="Line B", color="green", linestyle="-", marker="x")

ax.set_title('Graph. with Legend')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

# Shows the legend box
ax.legend()
#add the background grid
ax.grid(True)

plt.show()

# %% [markdown]
# # **Ticks — Customize Axis Numbers**
# used when we want to customize axis

# %%
plt.xticks([1, 2, 3, 4, 5])
plt.yticks([10, 15, 20, 25, 30])
# Out:
# ([<matplotlib.axis.YTick at 0x7fb8504d5150>,
# ...
#  [Text(0, 10, '10'),
#   Text(0, 15, '15'),
#   Text(0, 20, '20'),
#   Text(0, 25, '25'),
#   Text(0, 30, '30')])

# %% [markdown]
# | Feature    | Function                            | Example                         |
# | ---------- | ----------------------------------- | ------------------------------- |
# | Title      | `plt.title()` or `ax.set_title()`   | `"Chart Title"`                 |
# | X Label    | `plt.xlabel()` or `ax.set_xlabel()` | `"Time"`                        |
# | Y Label    | `plt.ylabel()` or `ax.set_ylabel()` | `"Value"`                       |
# | Grid       | `plt.grid(True)` or `ax.grid(True)` | Add grid lines                  |
# | Legend     | `plt.legend()` or `ax.legend()`     | Show line names                 |
# | Line Color | `color="red"`                       | Changes line color              |
# | Line Style | `linestyle="--"`                    | Dashed, dotted, etc.            |
# | Marker     | `marker="o"`                        | Adds symbols at each data point |
# | Tick Marks | `plt.xticks()`                      | Set specific numbers on axes    |

# %% [markdown]
# # **Subplots — Showing Multiple Charts in One Figure**
# Earlier we saw how subplot_mosaic() allows flexible layouts. Now let’s look at how to create multiple subplots using plt.subplots(), the standard grid approach.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# Create a figure with 1 row and 2 columns of subplots
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14,7))

# First subplot: Line chart
ax1.plot(x,y, color='blue', linestyle='--', marker='*')
ax1.set_title('Line plot')

ax2.scatter(x,y, color='red')
ax2.set_title('Scatter plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Annotations and Text in Matplotlib**
# annotations let you write text directly on the chart, next to the specific points, to explain what they mean.
#
# Mainly used for:
# * Highlight an important point
# * Show a value
# * Add a label to specific location

# %% [markdown]
# # **Basic function: ax.text(x,y, 'text', color='...')**
# we choose:
# * where to place the text --> (x,y)
# * what the text says --> 'some label'
# * What color to make it --> color='red'

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

#build  the subplotting
fig, ax = plt.subplots()

#draw the line
ax.plot(x,y)

#Annotate the specific point (x=3,y=15)
ax.text(3,15, 'Important Point', color='red')

#set the fields --> remember that we are working with ax
ax.set_title("Chart with Annotation")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")

plt.show()

# %% [markdown]
# We can also use ax.annotate() to draw arrows pointing to data

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

fig, ax = plt.subplots()

ax.plot(x,y)

ax.annotate("This peak", xy=(4, 25), xytext=(3, 28),
            arrowprops=dict(facecolor='black', arrowstyle='->'))

#set the fields --> remember that we are working with ax
ax.set_title("Chart with Annotation")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")

plt.show()

# %% [markdown]
# # **Styles and Themes**
# A style is like a present theme, it changes the colors, grid, font, and backgrounds of your plots automatically with just one line of code.

# %%
#how to use a predefined style?
plt.style.use("style_name")

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot') #apply the style before plotting

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

fig, ax = plt.subplots()
ax.plot(x,y)

ax.set_title('Styled plot')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

plt.show()

# %% [markdown]
# | Style Name          | Description                                           |
# | ------------------- | ----------------------------------------------------- |
# | `"default"`         | Matplotlib's standard look                            |
# | `"ggplot"`          | Based on R's ggplot2 style (red grid, clean look)     |
# | `"seaborn"`         | Soft colors, pretty fonts (used with seaborn library) |
# | `"bmh"`             | Clean and readable                                    |
# | `"dark_background"` | Great for dark mode or presentations                  |
# | `"Solarize_Light2"` | Light theme with strong contrast                      |

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# # **Saving topics**
# How to export our charts as image files? we can use: **plt.savefig("filename.png")**

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.plot(x,y)
plt.title('Plot to save')

# Save the plot to a file
plt.savefig('my_plot.png')

plt.show()

# %% [markdown]
# | Command                     | Purpose              |
# | --------------------------- | -------------------- |
# | `plt.savefig("name.png")`   | Save chart as PNG    |
# | `dpi=300`                   | High resolution      |
# | `bbox_inches="tight"`       | Trim whitespace      |
# | Use **before** `plt.show()` | Prevent blank images |

# %% [markdown]
# # **Colormaps**
# a colormap gradient of colors used to represent data **intensity**, **heat**, or **categories**. <br><br>
# They are very useful in:
# * heatmaps
# * Scatter Plots(color by value)
# * 3D surface plots
# * Image data

# %% [markdown]
# # **Heatmap**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create random 2D data (10x10 grid) of random numbers between 0 and 1
data = np.random.rand(10,10)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(6,5))

# Show the data as a heatmap using the "viridis" colormap
im = ax.imshow(data, cmap='viridis')

# Add a color bar (legend for colors)
cbar = ax.figure.colorbar(im, ax=ax) #adds the colorbar to the figure, using the heatmap im, and placing the colorbar relative the the main axes
cbar.ax.set_ylabel('Value', rotation=-90, va="bottom")#sets the label the the colorbar, and then rotates the text vertically. Finally alligns the text using bottom

plt.title("Heatmap with Colormap")
plt.show()

# %% [markdown]
# A heatmap helps you:
# * Quickly spot patterns or anomalies
# * Compare which areas have higher or lower values
# * See clusters, gradients, and trends
#
# These show the highest and lowest values. <br>
# Find any square that’s bright **yellow** → those are your highest values (close to 1).<br>
# Find any square that’s dark **purple** → those are your lowest values (close to 0).

# %% [markdown]
# | Name         | Description                        |
# | ------------ | ---------------------------------- |
# | `"viridis"`  | Smooth blue→green→yellow (default) |
# | `"plasma"`   | Purple→yellow                      |
# | `"inferno"`  | Black→red→orange                   |
# | `"magma"`    | Black→red→white                    |
# | `"cividis"`  | For color blindness                |
# | `"coolwarm"` | Diverging from cool to warm        |
